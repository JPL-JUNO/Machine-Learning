# %%
print("""
@Description: Nonlinear dimensionality reduction and visualization
@Author(s): Stephen CUI
@LastEditor(s): Stephen CUI
@CreatedTime: 2023-06-11 01:31:54
""")
# Out:
# @Description: Nonlinear dimensionality reduction and visualization
# @Author(s): Stephen CUI
# @LastEditor(s): Stephen CUI
# @CreatedTime: 2023-06-11 01:31:54

# %%
import sys
sys.path.append('./')
sys.path.append('../')

# %% [markdown]
# # Nonlinear dimensionality reduction and visualization

# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt
digits = load_digits()
fig, ax = plt.subplots(1, 4)
for i in range(4):
    ax[i].imshow(digits.images[i], cmap='Greys')
plt.show()

# %%
assert digits.data.shape == (1797, 64)

# %%
X_digits = digits.data
y_digits = digits.target
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, init='pca', random_state=123)
X_digits_tsne = tsne.fit_transform(X_digits)

# %%
from utilsML.visualize import plot_project
plot_project(X_digits_tsne, y_digits)
plt.show()
